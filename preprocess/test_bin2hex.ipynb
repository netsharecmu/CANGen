# %%
import pandas as pd

def convert_dataframe(df):
    # Function to convert CAN_ID fields to a hex string
    def convert_can_id(row):
        binary_string = ''.join([str(row[f'CAN_ID_{i}']) for i in range(11)])
        return '{:04x}'.format(int(binary_string, 2))

    # Function to convert DATA fields based on DLC
    def convert_data(row):
        bits_to_consider = int(row['DLC']) * 8
        data_bits = ''.join([str(int(row[f'DATA_{i}'])) for i in range(bits_to_consider)])
        return [f'{int(data_bits[i:i+8], 2):02x}' for i in range(0, len(data_bits), 8)]

    # Create a new dataframe for the converted data
    converted_df = pd.DataFrame()
    converted_df['Timestamp'] = df['Timestamp']
    converted_df['CAN_ID_HEX'] = df.apply(convert_can_id, axis=1)
    
    # Convert DATA fields
    data_transformed = df.apply(convert_data, axis=1).tolist()
    for i in range(8):
        converted_df[f'DATA_{i}'] = [item[i] if i < len(item) else '' for item in data_transformed]

    # Copy the Label column
    converted_df['Label'] = df['Label']

    return converted_df

# Example usage
# converted_df = convert_dataframe('path_to_your_csv_file.csv')

# %%
df = pd.read_csv("../data_selected/car_hacking/DoS_dataset_aligned_train_bits.csv", nrows=50)
converted_df = convert_dataframe(df)
converted_df
# converted_df.to_csv("test.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/sniperyyc/Documents/Research/CANGen/preprocess/test_bin2hex.ipynb Cell 2 line 2
#       <a href='vscode-notebook-cell:/Users/sniperyyc/Documents/Research/CANGen/preprocess/test_bin2hex.ipynb#W1sZmlsZQ%3D%3D?line=0'>1</a> df = pd.read_csv("../data_selected/car_hacking/DoS_dataset_aligned_train_bits.csv", nrows=50)
# ----> <a href='vscode-notebook-cell:/Users/sniperyyc/Documents/Research/CANGen/preprocess/test_bin2hex.ipynb#W1sZmlsZQ%3D%3D?line=1'>2</a> converted_df = convert_dataframe(df)
#       <a href='vscode-notebook-cell:/Users/sniperyyc/Documents/Research/CANGen/preprocess/test_bin2hex.ipynb#W1sZmlsZQ%3D%3D?line=2'>3</a> converted_df
#       <a href='vscode-notebook-cell:/Users/sniperyyc/Documents/Research/CANGen/preprocess/test_bin2hex.ipynb#W1sZmlsZQ%3D%3D?line=3'>4</a> # converted_df.to_csv("test.csv", index=False)
#
# /Users/sniperyyc/Documents/Research/CANGen/preprocess/test_bin2hex.ipynb Cell 2 line 2
#      <a href='vscode-notebook-cell:/Users/sniperyyc/Documents/Research/CANGen/preprocess/test_bin2hex.ipynb#W1sZmlsZQ%3D%3D?line=17'>18</a> converted_df['CAN_ID_HEX'] = df.apply(convert_can_id, axis=1)
#      <a href='vscode-notebook-cell:/Users/sniperyyc/Documents/Research/CANGen/preprocess/test_bin2hex.ipynb#W1sZmlsZQ%3D%3D?line=19'>20</a> # Convert DATA fields
# ---> <a href='vscode-notebook-cell:/Users/sniperyyc/Documents/Research/CANGen/preprocess/test_bin2hex.ipynb#W1sZmlsZQ%3D%3D?line=20'>21</a> data_transformed = df.apply(convert_data, axis=1).tolist()
#      <a href='vscode-notebook-cell:/Users/sniperyyc/Documents/Research/CANGen/preprocess/test_bin2hex.ipynb#W1sZmlsZQ%3D%3D?line=21'>22</a> for i in range(8):
#      <a href='vscode-notebook-cell:/Users/sniperyyc/Documents/Research/CANGen/preprocess/test_bin2hex.ipynb#W1sZmlsZQ%3D%3D?line=22'>23</a>     converted_df[f'DATA_{i}'] = [item[i] if i < len(item) else '' for item in data_transformed]
#
# File ~/anaconda3/envs/CANGen/lib/python3.9/site-packages/pandas/core/frame.py:10034, in DataFrame.apply(self, func, axis, raw, result_type, args, by_row, **kwargs)
#   10022 from pandas.core.apply import frame_apply
#   10024 op = frame_apply(
#   10025     self,
#   10026     func=func,
#    (...)
#   10032     kwargs=kwargs,
#   10033 )
# > 10034 return op.apply().__finalize__(self, method="apply")
#
# File ~/anaconda3/envs/CANGen/lib/python3.9/site-packages/pandas/core/apply.py:837, in FrameApply.apply(self)
#     834 elif self.raw:
#     835     return self.apply_raw()
# --> 837 return self.apply_standard()
#
# File ~/anaconda3/envs/CANGen/lib/python3.9/site-packages/pandas/core/apply.py:963, in FrameApply.apply_standard(self)
#     962 def apply_standard(self):
# --> 963     results, res_index = self.apply_series_generator()
#     965     # wrap results
#     966     return self.wrap_results(results, res_index)
#
# File ~/anaconda3/envs/CANGen/lib/python3.9/site-packages/pandas/core/apply.py:979, in FrameApply.apply_series_generator(self)
#     976 with option_context("mode.chained_assignment", None):
#     977     for i, v in enumerate(series_gen):
#     978         # ignore SettingWithCopy here in case the user mutates
# --> 979         results[i] = self.func(v, *self.args, **self.kwargs)
#     980         if isinstance(results[i], ABCSeries):
#     981             # If we have a view on v, we need to make a copy because
#     982             #  series_generator will swap out the underlying data
#     983             results[i] = results[i].copy(deep=False)
#
# /Users/sniperyyc/Documents/Research/CANGen/preprocess/test_bin2hex.ipynb Cell 2 line 1
#      <a href='vscode-notebook-cell:/Users/sniperyyc/Documents/Research/CANGen/preprocess/test_bin2hex.ipynb#W1sZmlsZQ%3D%3D?line=10'>11</a> bits_to_consider = int(row['DLC']) * 8
#      <a href='vscode-notebook-cell:/Users/sniperyyc/Documents/Research/CANGen/preprocess/test_bin2hex.ipynb#W1sZmlsZQ%3D%3D?line=11'>12</a> data_bits = ''.join([str(row[f'DATA_{i}']) for i in range(bits_to_consider)])
# ---> <a href='vscode-notebook-cell:/Users/sniperyyc/Documents/Research/CANGen/preprocess/test_bin2hex.ipynb#W1sZmlsZQ%3D%3D?line=12'>13</a> return [f'{int(data_bits[i:i+8], 2):02x}' for i in range(0, len(data_bits), 8)]
#
# /Users/sniperyyc/Documents/Research/CANGen/preprocess/test_bin2hex.ipynb Cell 2 line 1
#      <a href='vscode-notebook-cell:/Users/sniperyyc/Documents/Research/CANGen/preprocess/test_bin2hex.ipynb#W1sZmlsZQ%3D%3D?line=10'>11</a> bits_to_consider = int(row['DLC']) * 8
#      <a href='vscode-notebook-cell:/Users/sniperyyc/Documents/Research/CANGen/preprocess/test_bin2hex.ipynb#W1sZmlsZQ%3D%3D?line=11'>12</a> data_bits = ''.join([str(row[f'DATA_{i}']) for i in range(bits_to_consider)])
# ---> <a href='vscode-notebook-cell:/Users/sniperyyc/Documents/Research/CANGen/preprocess/test_bin2hex.ipynb#W1sZmlsZQ%3D%3D?line=12'>13</a> return [f'{int(data_bits[i:i+8], 2):02x}' for i in range(0, len(data_bits), 8)]
#
# ValueError: invalid literal for int() with base 2: '0.00.00.'

# %%
raw_df = pd.read_csv("../data_selected/car_hacking/DoS_dataset_aligned_train.csv", nrows=50)
raw_df
# Out:
#        Timestamp CAN_ID  DLC DATA_0 DATA_1 DATA_2 DATA_3 DATA_4 DATA_5 DATA_6  \
# 0   1.478198e+09   018f    8     fe     5b     00     00     00     3c     00
# 1   1.478198e+09   0260    8     19     21     22     30     08     8e     6d
# 2   1.478198e+09   0130    8     08     80     00     ff     31     80     0b
# 3   1.478198e+09   0140    8     00     00     00     00     08     22     2b
# 4   1.478198e+09   02a0    8     04     00     9a     1d     97     02     bd
# 5   1.478198e+09   04b1    8     29     27     27     23     00     00     00
# 6   1.478198e+09   0350    8     05     20     24     68     77     00     00
# 7   1.478198e+09   0130    8     0b     80     00     ff     45     80     0c
# 8   1.478198e+09   0370    8     00     20     00     00     00     00     00
# 9   1.478198e+09   0440    8     ff     00     00     00     ff     cd     08
# 10  1.478198e+09   0316    8     05     21     68     09     21     21     00
# 11  1.478198e+09   02c0    8     14     00     00     00     00     00     00
# 12  1.478198e+09   0350    8     05     20     44     68     76     00     00
# 13  1.478198e+09   0370    8     00     20     00     00     00     00     00
# 14  1.478198e+09   0440    8     ff     00     00     00     ff     ca     08
# 15  1.478198e+09   0329    8     40     bb     7f     14     11     20     00
# 16  1.478198e+09   0440    8     ff     00     00     00     ff     c9     08
# 17  1.478198e+09   0260    8     19     22     22     30     08     8e     71
# 18  1.478198e+09   0153    8     00     21     10     ff     00     ff     00
# 19  1.478198e+09   02c0    8     14     00     00     00     00     00     00
# 20  1.478198e+09   0131    8     0e     80     00     00     55     7f     00
# 21  1.478198e+09   0316    8     05     22     60     09     22     21     00
# 22  1.478198e+09   02a0    8     24     00     9a     1d     97     02     bd
# 23  1.478198e+09   0002    8     00     00     00     00     00     03     01
# 24  1.478198e+09   0440    8     ff     00     00     00     ff     c9     08
# 25  1.478198e+09   0260    8     19     22     22     30     08     8e     70
# 26  1.478198e+09   02a0    8     44     00     9a     1d     97     02     bd
# 27  1.478198e+09   05f0    2     01     00    NaN    NaN    NaN    NaN    NaN
# 28  1.478198e+09   01f1    8     08     00     00     00     00     00     00
# 29  1.478198e+09   0329    8     86     bb     7f     14     11     20     00
# 30  1.478198e+09   0002    8     00     00     00     00     00     03     03
# 31  1.478198e+09   0350    8     05     20     94     68     77     00     00
# 32  1.478198e+09   04b1    8     29     27     27     23     00     00     00
# 33  1.478198e+09   0153    8     00     21     10     ff     00     ff     00
# 34  1.478198e+09   0350    8     05     20     a4     68     77     00     00
# 35  1.478198e+09   0130    8     12     80     00     ff     0e     80     04
# 36  1.478198e+09   0316    8     05     21     68     09     21     21     00
# 37  1.478198e+09   0260    8     19     21     22     30     08     8e     6e
# 38  1.478198e+09   0153    8     00     21     10     ff     00     ff     00
# 39  1.478198e+09   0153    8     00     21     10     ff     00     ff     00
# 40  1.478198e+09   0316    8     05     21     68     09     21     21     00
# 41  1.478198e+09   0370    8     00     20     00     00     00     00     00
# 42  1.478198e+09   04f0    8     00     00     00     80     00     69     d1
# 43  1.478198e+09   0153    8     00     21     10     ff     00     ff     00
# 44  1.478198e+09   0002    8     00     00     00     00     00     04     08
# 45  1.478198e+09   0140    8     00     00     00     00     08     20     28
# 46  1.478198e+09   0131    8     e5     7f     00     00     18     7f     09
# 47  1.478198e+09   043f    8     00     40     60     ff     7e     c4     08
# 48  1.478198e+09   0316    8     05     22     60     09     22     21     00
# 49  1.478198e+09   018f    8     fe     5b     00     00     00     3c     00
#
#    DATA_7 Label
# 0      00     R
# 1      3a     R
# 2      7f     R
# 3      a3     R
# 4      00     R
# 5      9a     R
# 6      1e     R
# 7      85     R
# 8      00     R
# 9      00     R
# 10     6f     R
# 11     00     R
# 12     7f     R
# 13     00     R
# 14     00     R
# 15     14     R
# 16     00     R
# 17     03     R
# 18     00     R
# 19     00     R
# 20     d2     R
# 21     6f     R
# 22     00     R
# 23     c3     R
# 24     00     R
# 25     26     R
# 26     00     R
# 27    NaN     R
# 28     00     R
# 29     14     R
# 30     f9     R
# 31     ae     R
# 32     9a     R
# 33     00     R
# 34     9e     R
# 35     bb     R
# 36     6f     R
# 37     17     R
# 38     00     R
# 39     00     R
# 40     6f     R
# 41     00     R
# 42     13     R
# 43     00     R
# 44     cf     R
# 45     1c     R
# 46     ee     R
# 47     00     R
# 48     6f     R
# 49     00     R

# %%
df = pd.read_csv("test.csv")

# %%
df
# Out:
#        Timestamp CAN_ID_HEX DATA_0 DATA_1 DATA_2 DATA_3 DATA_4 DATA_5 DATA_6  \
# 0   1.478198e+09       018f     fe     5b     00     00     00     3c     00
# 1   1.478198e+09       0260     19     21     22     30     08     8e     6d
# 2   1.478198e+09       0130     08     80     00     ff     31     80     0b
# 3   1.478198e+09       0140     00     00     00     00     08     22     2b
# 4   1.478198e+09       02a0     04     00     9a     1d     97     02     bd
# 5   1.478198e+09       04b1     29     27     27     23     00     00     00
# 6   1.478198e+09       0350     05     20     24     68     77     00     00
# 7   1.478198e+09       0130     0b     80     00     ff     45     80     0c
# 8   1.478198e+09       0370     00     20     00     00     00     00     00
# 9   1.478198e+09       0440     ff     00     00     00     ff     cd     08
# 10  1.478198e+09       0316     05     21     68     09     21     21     00
# 11  1.478198e+09       02c0     14     00     00     00     00     00     00
# 12  1.478198e+09       0350     05     20     44     68     76     00     00
# 13  1.478198e+09       0370     00     20     00     00     00     00     00
# 14  1.478198e+09       0440     ff     00     00     00     ff     ca     08
# 15  1.478198e+09       0329     40     bb     7f     14     11     20     00
# 16  1.478198e+09       0440     ff     00     00     00     ff     c9     08
# 17  1.478198e+09       0260     19     22     22     30     08     8e     71
# 18  1.478198e+09       0153     00     21     10     ff     00     ff     00
# 19  1.478198e+09       02c0     14     00     00     00     00     00     00
# 20  1.478198e+09       0131     0e     80     00     00     55     7f     00
# 21  1.478198e+09       0316     05     22     60     09     22     21     00
# 22  1.478198e+09       02a0     24     00     9a     1d     97     02     bd
# 23  1.478198e+09       0002     00     00     00     00     00     03     01
# 24  1.478198e+09       0440     ff     00     00     00     ff     c9     08
# 25  1.478198e+09       0260     19     22     22     30     08     8e     70
# 26  1.478198e+09       02a0     44     00     9a     1d     97     02     bd
# 27  1.478198e+09       05f0     01     00    NaN    NaN    NaN    NaN    NaN
# 28  1.478198e+09       01f1     08     00     00     00     00     00     00
# 29  1.478198e+09       0329     86     bb     7f     14     11     20     00
# 30  1.478198e+09       0002     00     00     00     00     00     03     03
# 31  1.478198e+09       0350     05     20     94     68     77     00     00
# 32  1.478198e+09       04b1     29     27     27     23     00     00     00
# 33  1.478198e+09       0153     00     21     10     ff     00     ff     00
# 34  1.478198e+09       0350     05     20     a4     68     77     00     00
# 35  1.478198e+09       0130     12     80     00     ff     0e     80     04
# 36  1.478198e+09       0316     05     21     68     09     21     21     00
# 37  1.478198e+09       0260     19     21     22     30     08     8e     6e
# 38  1.478198e+09       0153     00     21     10     ff     00     ff     00
# 39  1.478198e+09       0153     00     21     10     ff     00     ff     00
# 40  1.478198e+09       0316     05     21     68     09     21     21     00
# 41  1.478198e+09       0370     00     20     00     00     00     00     00
# 42  1.478198e+09       04f0     00     00     00     80     00     69     d1
# 43  1.478198e+09       0153     00     21     10     ff     00     ff     00
# 44  1.478198e+09       0002     00     00     00     00     00     04     08
# 45  1.478198e+09       0140     00     00     00     00     08     20     28
# 46  1.478198e+09       0131     e5     7f     00     00     18     7f     09
# 47  1.478198e+09       043f     00     40     60     ff     7e     c4     08
# 48  1.478198e+09       0316     05     22     60     09     22     21     00
# 49  1.478198e+09       018f     fe     5b     00     00     00     3c     00
#
#    DATA_7 Label
# 0      00     R
# 1      3a     R
# 2      7f     R
# 3      a3     R
# 4      00     R
# 5      9a     R
# 6      1e     R
# 7      85     R
# 8      00     R
# 9      00     R
# 10     6f     R
# 11     00     R
# 12     7f     R
# 13     00     R
# 14     00     R
# 15     14     R
# 16     00     R
# 17     03     R
# 18     00     R
# 19     00     R
# 20     d2     R
# 21     6f     R
# 22     00     R
# 23     c3     R
# 24     00     R
# 25     26     R
# 26     00     R
# 27    NaN     R
# 28     00     R
# 29     14     R
# 30     f9     R
# 31     ae     R
# 32     9a     R
# 33     00     R
# 34     9e     R
# 35     bb     R
# 36     6f     R
# 37     17     R
# 38     00     R
# 39     00     R
# 40     6f     R
# 41     00     R
# 42     13     R
# 43     00     R
# 44     cf     R
# 45     1c     R
# 46     ee     R
# 47     00     R
# 48     6f     R
# 49     00     R
