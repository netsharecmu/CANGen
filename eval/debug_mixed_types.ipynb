# %%
import pandas as pd

# %%
df = pd.read_csv("../data_selected/car_hacking/tabddpm_car-hacking-rpm-bits_20231212164000615.csv")
# Out:
# /var/folders/5t/wpyxbs_903nbb1sr78d2hhnc0000gn/T/ipykernel_19939/2584380953.py:1: DtypeWarning: Columns (5,6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("../data_selected/car_hacking/tabddpm_car-hacking-rpm-bits_20231212164000615.csv")

# %%
df['DATA_3'].map(type).unique()
# Out:
# array([<class 'str'>, <class 'float'>], dtype=object)

# %%
df[df['DATA_3'].apply(lambda x: isinstance(x, float))]
# Out:
#            Timestamp CAN_ID  DLC DATA_0 DATA_1 DATA_2 DATA_3 DATA_4 DATA_5  \
# 2       1.478191e+09   04c0    2     00     00    NaN    NaN    NaN    NaN
# 4       1.478191e+09   04c0    2     00     00    NaN    NaN    NaN    NaN
# 6       1.478191e+09   04c0    2     00     00    NaN    NaN    NaN    NaN
# 8       1.478191e+09   0316    2     45     29    NaN    NaN    NaN    NaN
# 11      1.478191e+09   04c0    2     00     00    NaN    NaN    NaN    NaN
# ...              ...    ...  ...    ...    ...    ...    ...    ...    ...
# 699995  1.478201e+09   0131    8     f3     7f    0.0    0.0     1d     7f
# 699996  1.478201e+09   0740    2     00     00    NaN    NaN    NaN    NaN
# 699997  1.478201e+09   0300    2     04     00    NaN    NaN    NaN    NaN
# 699998  1.478201e+09   0740    2     00     00    NaN    NaN    NaN    NaN
# 699999  1.478201e+09   0300    2     04     00    NaN    NaN    NaN    NaN
#
#        DATA_6 DATA_7 Label
# 2         NaN    NaN     R
# ...

# %%
df['DATA_2'].to_list()
# Out:
# [0.0,
#  24.0,
#  nan,
#  24.0,
#  nan,
#  24.0,
#  nan,
#  0.0,
#  nan,
#  0.0,
#  0.0,
#  nan,
#  24.0,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  24.0,
#  nan,
#  nan,
#  nan,
#  nan,
#  0.0,
#  0.0,
#  nan,
#  nan,
#  nan,
#  nan,
#  24.0,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  24.0,
#  24.0,
#  nan,
#  24.0,
#  nan,
#  nan,
#  0.0,
#  nan,
#  24.0,
#  24.0,
#  nan,
#  24.0,
#  nan,
#  0.0,
#  24.0,
#  24.0,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  24.0,
#  0.0,
#  nan,
#  nan,
#  nan,
#  nan,
#  24.0,
#  0.0,
#  24.0,
#  nan,
#  24.0,
#  0.0,
#  24.0,
#  nan,
#  0.0,
#  nan,
#  nan,
#  0.0,
#  nan,
#  nan,
#  nan,
#  0.0,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  24.0,
#  24.0,
#  24.0,
#  nan,
#  0.0,
#  0.0,
#  24.0,
#  24.0,
#  nan,
#  nan,
#  24.0,
#  nan,
#  nan,
#  nan,
#  0.0,
#  nan,
#  nan,
#  24.0,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  24.0,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  24.0,
#  nan,
#  24.0,
#  nan,
#  nan,
#  0.0,
#  nan,
# ...

# %%
df['DATA_2'].apply(lambda x: isinstance(x, float))
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
#           ...
# 699995    True
# 699996    True
# 699997    True
# 699998    True
# 699999    True
# Name: DATA_2, Length: 700000, dtype: bool

# %%
df.dtypes
# Out:
# Timestamp    float64
# CAN_ID        object
# DLC            int64
# DATA_0        object
# DATA_1        object
# DATA_2        object
# DATA_3        object
# DATA_4        object
# DATA_5        object
# DATA_6        object
# DATA_7        object
# Label         object
# dtype: object
