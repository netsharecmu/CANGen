# %%
'''
Pick finally used csv for evaluation
'''

import pandas as pd

import os

# %%
csv_target_folder = "../results/vehiclesec2024/small-scale/csv_selected"

file_map = {}
for csv_file in os.listdir("../results/vehiclesec2024/small-scale/csv"):
    if not csv_file.endswith(".csv"):
        continue
    model_name, dataset_name, timestamp = os.path.splitext(os.path.basename(csv_file))[0].split("_")

    if model_name not in file_map:
        file_map[model_name] = {}
    if dataset_name not in file_map[model_name]:
        file_map[model_name][dataset_name] = []

    if model_name == "realtabformer-tabular":
        if not timestamp.startswith("20231130"):
            continue
    
    file_map[model_name][dataset_name].append(csv_file)

for model_name, dataset_files in file_map.items():
    for dataset_name, files in dataset_files.items():
        print(model_name, dataset_name, len(files))
# Out:
# realtabformer-tabular openxc-nyc-downtown-east 3
# realtabformer-tabular car-hacking-dos-hex 3
# realtabformer-tabular car-hacking-rpm-hex 3
# realtabformer-tabular car-hacking-gear-bits 3
# realtabformer-tabular car-hacking-fuzzy-bits 3
# realtabformer-tabular openxc-taiwan-highwayno2-can 3
# realtabformer-tabular openxc-india-new-delhi-railway-to-aiims-no-imputation 3
# realtabformer-tabular car-hacking-rpm-bits 3
# realtabformer-tabular car-hacking-dos-bits 3
# realtabformer-tabular car-hacking-fuzzy-hex 3
# realtabformer-tabular openxc-nyc-downtown-east-no-imputation 2
# realtabformer-tabular openxc-india-new-delhi-railway-to-aiims 3
# realtabformer-tabular openxc-taiwan-highwayno2-can-no-imputation 3
# realtabformer-tabular car-hacking-gear-hex 3
# realtabformer-tabular syncan-flag 0
# realtabformer-timeseries openxc-nyc-downtown-east-sessionized 10
# realtabformer-timeseries openxc-india-new-delhi-railway-to-aiims-sessionized 9
# realtabformer-timeseries car-hacking-gear-bits-sessionized 6
# realtabformer-timeseries car-hacking-rpm-bits-sessionized 6
# realtabformer-timeseries openxc-taiwan-highwayno2-can-sessionized 9
# realtabformer-timeseries syncan-flag-sessionized 10
# realtabformer-timeseries car-hacking-fuzzy-bits-sessionized 8
# realtabformer-timeseries car-hacking-dos-bits-sessionized 5
# tabddpm car-hacking-dos-bits 2
# tabddpm openxc-taiwan-highwayno2-can 3
# tabddpm openxc-nyc-downtown-east 4
# tabddpm openxc-india-new-delhi-railway-to-aiims 3
# tabddpm syncan-flag 1
# netshare openxc-nyc-downtown-east-sessionized 10
# netshare openxc-india-new-delhi-railway-to-aiims-sessionized 9
# netshare car-hacking-gear-bits-sessionized 3
# netshare car-hacking-rpm-bits-sessionized 3
# netshare openxc-taiwan-highwayno2-can-sessionized 9
# netshare syncan-flag-sessionized 4
# netshare car-hacking-fuzzy-bits-sessionized 3
# netshare car-hacking-dos-bits-sessionized 4
# ctgan car-hacking-fuzzy-bits 3
# ctgan openxc-nyc-downtown-east 4
# ctgan car-hacking-gear-bits 3
# ctgan car-hacking-dos-bits 4
# ctgan syncan-flag 4
# ctgan openxc-taiwan-highwayno2-can 3
# ctgan openxc-india-new-delhi-railway-to-aiims 3
# ctgan car-hacking-rpm-bits 3
